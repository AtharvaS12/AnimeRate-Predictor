# %% [markdown]
# # Anime Dataset Classification (ratings 1 to 10)

# %%
import pandas as pd

# %%
df = pd.read_csv('mal_anime.csv')
df.shape
# Out:
# (19931, 25)

# %% [markdown]
# # Preprocessing
# - Removing extra appearance of url.*: and id.*: --> pandas has done this task by removing 11 rows while loading
# - Covert duration column to minutes
# - Remove # from two columns
# - Genre, themes and producers :: remove comma and do OHE

# %%
df.head(1895).tail(5)
# Out:
#       myanimelist_id                                              title  \
# 1890            2083                                     Natsuki Crisis
# 1891            2084                              NG Knight Ramune & 40
# 1892            2085  NG Knight Ramune & 40 EX: Biku Biku Triangle A...
# 1893            2086  NG Knight Ramune & 40 DX: Wakuwaku Jikuu - Hon...
# 1894            2087                         VS Knight Lamune & 40 Fire
#
#                                             description  \
# 1890  Natsuki Kisumi has a passion for wrestling and...
# 1891  Lamune is an ordinary 4th grade boy who loves ...
# 1892  Lamune has returned to Earth with no memory of...
# 1893  Lamune and Da Cider head off to Puff-Puff Pala...
# 1894  Baba Lamunade is followed home by two strange ...
#
#                                                   image Type Episodes  \
# 1890  https://cdn.myanimelist.net/images/anime/1008/...  OVA        2
# 1891  https://cdn.myanimelist.net/images/anime/2/467...   TV       38
# 1892  https://cdn.myanimelist.net/images/anime/7/227...  OVA        3
# 1893  https://cdn.myanimelist.net/images/anime/8/215...  OVA        3
# 1894  https://cdn.myanimelist.net/images/anime/10/43...   TV       26
#
#                Status    Premiered Released_Season  Released_Year  ...  \
# 1890  Finished Airing          NaN             NaN            NaN  ...
# 1891  Finished Airing  Spring 1990          Spring         1990.0  ...
# 1892  Finished Airing          NaN             NaN            NaN  ...
# 1893  Finished Airing          NaN             NaN            NaN  ...
# 1894  Finished Airing  Spring 1996          Spring         1996.0  ...
#
#      Demographic         Duration                     Rating Score Ranked  \
# 1890         NaN  29 min. per ep.  PG-13 - Teens 13 or older  6.19  #9168
# 1891         NaN  22 min. per ep.  PG-13 - Teens 13 or older  7.02  #4458
# 1892         NaN  30 min. per ep.  PG-13 - Teens 13 or older  6.39  #8012
# 1893         NaN  30 min. per ep.  PG-13 - Teens 13 or older  6.41  #7915
# 1894         NaN  23 min. per ep.  PG-13 - Teens 13 or older  6.91  #4955
#
#      Popularity Members Favorites  \
# 1890      #9860   4,173         1
# 1891      #9242   5,080        24
# 1892     #12600   1,862         2
# 1893     #12626   1,842         3
# 1894      #9862   4,171        16
#
#                                              characters  \
# 1890  [{"id": 12057, "name": "Kandori, Akira", "url"...
# 1891  [{"id": 70087, "name": "Arara, Cocoa", "url": ...
# 1892  [{"id": 70087, "name": "Arara, Cocoa", "url": ...
# 1893  [{"id": 70087, "name": "Arara, Cocoa", "url": ...
# 1894  [{"id": 76822, "name": "Baba, Lemonade", "url"...
#
#                                              source_url
# 1890  https://myanimelist.net/anime/2083/Natsuki_Crisis
# 1891  https://myanimelist.net/anime/2084/NG_Knight_R...
# 1892  https://myanimelist.net/anime/2085/NG_Knight_R...
# 1893  https://myanimelist.net/anime/2086/NG_Knight_R...
# 1894  https://myanimelist.net/anime/2087/VS_Knight_L...
#
# [5 rows x 25 columns]

# %%
import numpy as np
def hrminsec(str_val):
    '''handle patterns like :: 
    1hr. 43min. 33 sec. per ep.
    Anything can be absent / present '''

    if pd.isna(str_val):
        return np.nan
    if str_val == " ":
        return np.nan
    l_val = str_val.split('.')
    sec_val = 0
    for e in l_val:
        if "hr" in e:
            v = e.split(" ")
            val = int(v[0])*60*60
        elif "min" in e:
            v = e.strip().split(" ")
            val = int(v[0])*60
        elif "sec" in e:
            v = e.strip().split(" ")
            val = int(v[0])
        else:
            val = 0
        sec_val += val
    return sec_val

# %%
df['duration_sec'] = df['Duration'].apply(hrminsec)

# %%
df['duration_sec'].describe()
# Out:
# count    19549.000000
# mean      1574.167323
# std       1587.085827
# min          0.000000
# 25%        420.000000
# 50%       1380.000000
# 75%       1620.000000
# max      10080.000000
# Name: duration_sec, dtype: float64

# %%
(df['duration_sec'] == 0).sum()
# Out:
# np.int64(624)

# %% [markdown]
# # Remove '#'

# %%
df['Ranked'] = df['Ranked'].str.replace("#","" )

# %%
df['Ranked'].iloc[:5]
# Out:
# 0      48
# 1     232
# 2     385
# 3    3344
# 4    4887
# Name: Ranked, dtype: object

# %%
df['Popularity'] = df['Popularity'].str.replace("#", "")

# %%
df['Popularity'].iloc[:5]
# Out:
# 0      42
# 1     649
# 2     265
# 3    1979
# 4    5765
# Name: Popularity, dtype: object

# %% [markdown]
# # Genre Themes and Studios --> remove, and do OHE

# %%
df.shape
# Out:
# (19931, 26)

# %%
ndf = df['Genres'].str.get_dummies(sep=",")
df = df.join(ndf)
df.shape
# Out:
# (19931, 67)

# %%
ndf = df['Themes'].str.get_dummies(sep=",")
df = df.join(ndf)
df.shape
# Out:
# (19931, 170)

# %%
ndf = df['Producers'].str.strip().str.get_dummies(sep=",")
df = df.join(ndf, lsuffix='l')
df.shape
# Out:
# (19931, 2370)

# %%
df['Score'].isna().sum()
# Out:
# np.int64(4692)

# %%
df = df[df['Score'].isna() == False]
df.shape
# Out:
# (15239, 2370)

# %% [markdown]
# ## Convert target column to categotical

# %%
df['Score'] = np.round(df['Score'])

# %%
df['Score'].value_counts(normalize=True)
# Out:
# Score
# 6.0    0.382965
# 7.0    0.373384
# 8.0    0.126583
# 5.0    0.098300
# 9.0    0.009843
# 4.0    0.006956
# 3.0    0.001706
# 2.0    0.000262
# Name: proportion, dtype: float64

# %% [markdown]
# ## Save the clean file

# %%
df.to_csv("clean.csv", index=False)
